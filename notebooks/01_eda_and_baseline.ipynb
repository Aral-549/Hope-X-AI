# %% [markdown]
# # HackBlox 2026 · 3LC Scene Classification Challenge
# ## 01. Exploratory Data Analysis & Error Diagnostics
#
# This notebook provides visual inspections of:
# 1. Dataset class distributions (Train 600 seed vs 6,000 undefined pool vs Val 1,200)
# 2. Embedding visualizations & high-loss sample diagnostics
# 3. Class confusion pair analysis (Glacier vs Mountain, Street vs Buildings)

# %%
from pathlib import Path
import yaml
import matplotlib.pyplot as plt
import seaborn as sns

with open('../configs/config.yaml') as f:
    config = yaml.safe_load(f)

print('Loaded Project:', config['project']['name'])
